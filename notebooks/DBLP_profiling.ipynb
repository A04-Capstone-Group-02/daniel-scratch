# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %config InlineBackend.figure_format = 'retina'

# %%
phrases5k, unigrams5k, multigrams5k, phrases, unigrams, multigrams = \
[pd.read_csv(f'../src/AutoPhrase/models/models/{filepath}', header=None, index_col=1, sep='\t', squeeze=True)
 for filepath in (
     'DBLP.5K/AutoPhrase.txt',
     'DBLP.5K/AutoPhrase_single-word.txt',
     'DBLP.5K/AutoPhrase_multi-words.txt',
     'DBLP/AutoPhrase.txt',
     'DBLP/AutoPhrase_single-word.txt',
     'DBLP/AutoPhrase_multi-words.txt',
 )]

# %%
phrases5k
# Out:
# 1
# programming languages    0.967942
# information retrieval    0.967465
# knowledge management     0.958949
# neural networks          0.956366
# concurrency control      0.954314
#                            ...
# related to               0.020027
# approaches to            0.019297
# mapping of               0.016110
# a multi                  0.015085
# use of                   0.014747
# Name: 0, Length: 1907, dtype: float64

# %%
phrases
# Out:
# 1
# ssl tls                                 0.985474
# laplacian eigenmaps                     0.985220
# inverse kinematics                      0.984385
# czech republic                          0.984106
# viral marketing                         0.983517
#                                           ...
# the number of iterations required to    0.007512
# of optimum combining in                 0.007475
# for state estimation of                 0.006796
# more significant as                     0.006778
# very important problem in               0.006639
# Name: 0, Length: 720381, dtype: float64

# %%
plt.hist([phrases5k, phrases], density=True);

# %%
phrases5k.gt(.5).mean(), phrases.gt(.5).mean()
# Out:
# (0.4352385946512847, 0.35651134607936635)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 3))
axes[0].hist([unigrams5k, multigrams5k], density=True)
axes[1].hist([unigrams, multigrams], density=True);
